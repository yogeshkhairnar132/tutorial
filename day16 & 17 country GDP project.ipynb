# %%
import pandas as pd
# use for dataframes

# %%
# how to read tha dataset
stats=pd.read_csv(r"E:\Data Science\senapati\day16\data.csv")
stats
# Out:
#               CountryName CountryCode  BirthRate  InternetUsers  \
# 0                   Aruba         ABW     10.244           78.9
# 1             Afghanistan         AFG     35.253            5.9
# 2                  Angola         AGO     45.985           19.1
# 3                 Albania         ALB     12.877           57.2
# 4    United Arab Emirates         ARE     11.044           88.0
# ..                    ...         ...        ...            ...
# 190           Yemen, Rep.         YEM     32.947           20.0
# 191          South Africa         ZAF     20.850           46.5
# 192      Congo, Dem. Rep.         COD     42.394            2.2
# 193                Zambia         ZMB     40.471           15.4
# 194              Zimbabwe         ZWE     35.715           18.5
#
#              IncomeGroup
# 0            High income
# 1             Low income
# 2    Upper middle income
# 3    Upper middle income
# 4            High income
# ..                   ...
# ...

# %%
# explore data in python
# 1. full dataframes
# 2. how many rows & columns. you have to click to check the no. of rows should matched wioth client data
len(stats)
# printed no. of rows
# Out:
# 195

# %%
#3. see columns
stats.columns
# print columns name only (not printed all columns)
# Out:
# Index(['CountryName', 'CountryCode', 'BirthRate', 'InternetUsers',
#        'IncomeGroup'],
#       dtype='object')

# %%
#4. numbers of columns
len(stats.columns)
# printed numbers of columns
# Out:
# 5

# %%
#5. top rows
stats.head()
# by default it print top 5 rows if not mentioned
# Out:
#             CountryName CountryCode  BirthRate  InternetUsers  \
# 0                 Aruba         ABW     10.244           78.9
# 1           Afghanistan         AFG     35.253            5.9
# 2                Angola         AGO     45.985           19.1
# 3               Albania         ALB     12.877           57.2
# 4  United Arab Emirates         ARE     11.044           88.0
#
#            IncomeGroup
# 0          High income
# 1           Low income
# 2  Upper middle income
# 3  Upper middle income
# 4          High income

# %%
#6. botoom 5 rows
stats.tail()
# by default it print botton 5 rows
# Out:
#           CountryName CountryCode  BirthRate  InternetUsers  \
# 190       Yemen, Rep.         YEM     32.947           20.0
# 191      South Africa         ZAF     20.850           46.5
# 192  Congo, Dem. Rep.         COD     42.394            2.2
# 193            Zambia         ZMB     40.471           15.4
# 194          Zimbabwe         ZWE     35.715           18.5
#
#              IncomeGroup
# 190  Lower middle income
# 191  Upper middle income
# 192           Low income
# 193  Lower middle income
# 194           Low income

# %%
stats.head(15)
# print top 15 rows as we mentioned
# Out:
#              CountryName CountryCode  BirthRate  InternetUsers  \
# 0                  Aruba         ABW     10.244        78.9000
# 1            Afghanistan         AFG     35.253         5.9000
# 2                 Angola         AGO     45.985        19.1000
# 3                Albania         ALB     12.877        57.2000
# 4   United Arab Emirates         ARE     11.044        88.0000
# 5              Argentina         ARG     17.716        59.9000
# 6                Armenia         ARM     13.308        41.9000
# 7    Antigua and Barbuda         ATG     16.447        63.4000
# 8              Australia         AUS     13.200        83.0000
# 9                Austria         AUT      9.400        80.6188
# 10            Azerbaijan         AZE     18.300        58.7000
# 11               Burundi         BDI     44.151         1.3000
# 12               Belgium         BEL     11.200        82.1702
# 13                 Benin         BEN     36.440         4.9000
# ...

# %%
stats.tail(54)
# print bottom 54 rows as we mentioned
# Out:
#                         CountryName CountryCode  BirthRate  InternetUsers  \
# 141                     Puerto Rico         PRI     10.800        73.9000
# 142                        Portugal         PRT      7.900        62.0956
# 143                        Paraguay         PRY     21.588        36.9000
# 144                French Polynesia         PYF     16.393        56.8000
# 145                           Qatar         QAT     11.940        85.3000
# 146                         Romania         ROU      8.800        49.7645
# 147              Russian Federation         RUS     13.200        67.9700
# 148                          Rwanda         RWA     32.689         9.0000
# 149                    Saudi Arabia         SAU     20.576        60.5000
# 150                           Sudan         SDN     33.477        22.7000
# 151                         Senegal         SEN     38.533        13.1000
# 152                       Singapore         SGP      9.300        81.0000
# ...

# %%
#7. information of column
stats.info()
# strings are called as object
# if strings are there then dtype is object
# if integer are there then dtype is float64
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 195 entries, 0 to 194
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   CountryName    195 non-null    object
#  1   CountryCode    195 non-null    object
#  2   BirthRate      195 non-null    float64
#  3   InternetUsers  195 non-null    float64
#  4   IncomeGroup    195 non-null    object
# dtypes: float64(2), object(3)
# memory usage: 7.7+ KB

# %%
stats.info(54)
# if strings are there then dtype is object
# if integer are there then dtype is float64
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 195 entries, 0 to 194
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   CountryName    195 non-null    object
#  1   CountryCode    195 non-null    object
#  2   BirthRate      195 non-null    float64
#  3   InternetUsers  195 non-null    float64
#  4   IncomeGroup    195 non-null    object
# dtypes: float64(2), object(3)
# memory usage: 7.7+ KB

# %%
#8. get stats on the columns
stats.describe()
# it will work like a statistic fun
# Out:
#         BirthRate  InternetUsers
# count  195.000000     195.000000
# mean    21.469928      42.076471
# std     10.605467      29.030788
# min      7.900000       0.900000
# 25%     12.120500      14.520000
# 50%     19.680000      41.000000
# 75%     29.759500      66.225000
# max     49.661000      96.546800

# %%
stats.head()
# Out:
#             CountryName CountryCode  BirthRate  InternetUsers  \
# 0                 Aruba         ABW     10.244           78.9
# 1           Afghanistan         AFG     35.253            5.9
# 2                Angola         AGO     45.985           19.1
# 3               Albania         ALB     12.877           57.2
# 4  United Arab Emirates         ARE     11.044           88.0
#
#            IncomeGroup
# 0          High income
# 1           Low income
# 2  Upper middle income
# 3  Upper middle income
# 4          High income

# %%
stats.describe().transpose()
# transpose convert columns into rows
# Out:
#    count       mean        std  min      25%    50%      75%      max
# c  195.0  21.469928  10.605467  7.9  12.1205  19.68  29.7595  49.6610
# d  195.0  42.076471  29.030788  0.9  14.5200  41.00  66.2250  96.5468

# %%
stats.columns
# Out:
# Index(['a', 'b', 'c', 'd', 'e'], dtype='object')

# %%
stats.columns=['a','b','c','d','e']
stats.head()
# we change the columns name
# Out:
#                       a    b       c     d                    e
# 0                 Aruba  ABW  10.244  78.9          High income
# 1           Afghanistan  AFG  35.253   5.9           Low income
# 2                Angola  AGO  45.985  19.1  Upper middle income
# 3               Albania  ALB  12.877  57.2  Upper middle income
# 4  United Arab Emirates  ARE  11.044  88.0          High income

# %%
stats.columns=['CountryName', 'CountryCode', 'BirthRate', 'InternetUsers',
       'IncomeGroup']
stats.head()
# here we change again columns name
# Out:
#             CountryName CountryCode  BirthRate  InternetUsers  \
# 0                 Aruba         ABW     10.244           78.9
# 1           Afghanistan         AFG     35.253            5.9
# 2                Angola         AGO     45.985           19.1
# 3               Albania         ALB     12.877           57.2
# 4  United Arab Emirates         ARE     11.044           88.0
#
#            IncomeGroup
# 0          High income
# 1           Low income
# 2  Upper middle income
# 3  Upper middle income
# 4          High income

# %%
# subsetting a dataframes in pandas

#1. Rows
#2. Columns
#3. combine the two

# %%
# rows
stats[21:26]
# print 21 to 25 rows (n-1)
# Out:
#    CountryName CountryCode  BirthRate  InternetUsers          IncomeGroup
# 21      Belize         BLZ     23.092          33.60  Upper middle income
# 22     Bermuda         BMU     10.400          95.30          High income
# 23     Bolivia         BOL     24.236          36.94  Lower middle income
# 24      Brazil         BRA     14.931          51.04  Upper middle income
# 25    Barbados         BRB     12.188          73.00          High income

# %%
stats[:]
# print all rows & columns
# Out:
#               CountryName CountryCode  BirthRate  InternetUsers  \
# 0                   Aruba         ABW     10.244           78.9
# 1             Afghanistan         AFG     35.253            5.9
# 2                  Angola         AGO     45.985           19.1
# 3                 Albania         ALB     12.877           57.2
# 4    United Arab Emirates         ARE     11.044           88.0
# ..                    ...         ...        ...            ...
# 190           Yemen, Rep.         YEM     32.947           20.0
# 191          South Africa         ZAF     20.850           46.5
# 192      Congo, Dem. Rep.         COD     42.394            2.2
# 193                Zambia         ZMB     40.471           15.4
# 194              Zimbabwe         ZWE     35.715           18.5
#
#              IncomeGroup
# 0            High income
# 1             Low income
# 2    Upper middle income
# 3    Upper middle income
# 4            High income
# ..                   ...
# ...

# %%
stats[:10]
# print 0 to 9 rows (n-1)
# Out:
#             CountryName CountryCode  BirthRate  InternetUsers  \
# 0                 Aruba         ABW     10.244        78.9000
# 1           Afghanistan         AFG     35.253         5.9000
# 2                Angola         AGO     45.985        19.1000
# 3               Albania         ALB     12.877        57.2000
# 4  United Arab Emirates         ARE     11.044        88.0000
# 5             Argentina         ARG     17.716        59.9000
# 6               Armenia         ARM     13.308        41.9000
# 7   Antigua and Barbuda         ATG     16.447        63.4000
# 8             Australia         AUS     13.200        83.0000
# 9               Austria         AUT      9.400        80.6188
#
#            IncomeGroup
# 0          High income
# 1           Low income
# 2  Upper middle income
# 3  Upper middle income
# 4          High income
# 5          High income
# 6  Lower middle income
# 7          High income
# 8          High income
# 9          High income

# %%
stats.head(10)
# print 0 to 9 row  (n-1)
# Out:
#             CountryName CountryCode  BirthRate  InternetUsers  \
# 0                 Aruba         ABW     10.244        78.9000
# 1           Afghanistan         AFG     35.253         5.9000
# 2                Angola         AGO     45.985        19.1000
# 3               Albania         ALB     12.877        57.2000
# 4  United Arab Emirates         ARE     11.044        88.0000
# 5             Argentina         ARG     17.716        59.9000
# 6               Armenia         ARM     13.308        41.9000
# 7   Antigua and Barbuda         ATG     16.447        63.4000
# 8             Australia         AUS     13.200        83.0000
# 9               Austria         AUT      9.400        80.6188
#
#            IncomeGroup
# 0          High income
# 1           Low income
# 2  Upper middle income
# 3  Upper middle income
# 4          High income
# 5          High income
# 6  Lower middle income
# 7          High income
# 8          High income
# 9          High income

# %%
stats[::-1]
# print reverse
# Out:
#               CountryName CountryCode  BirthRate  InternetUsers  \
# 194              Zimbabwe         ZWE     35.715           18.5
# 193                Zambia         ZMB     40.471           15.4
# 192      Congo, Dem. Rep.         COD     42.394            2.2
# 191          South Africa         ZAF     20.850           46.5
# 190           Yemen, Rep.         YEM     32.947           20.0
# ..                    ...         ...        ...            ...
# 4    United Arab Emirates         ARE     11.044           88.0
# 3                 Albania         ALB     12.877           57.2
# 2                  Angola         AGO     45.985           19.1
# 1             Afghanistan         AFG     35.253            5.9
# 0                   Aruba         ABW     10.244           78.9
#
#              IncomeGroup
# 194           Low income
# 193  Lower middle income
# 192           Low income
# 191  Upper middle income
# 190  Lower middle income
# ..                   ...
# ...

# %%
stats
# Out:
#               CountryName CountryCode  BirthRate  InternetUsers  \
# 0                   Aruba         ABW     10.244           78.9
# 1             Afghanistan         AFG     35.253            5.9
# 2                  Angola         AGO     45.985           19.1
# 3                 Albania         ALB     12.877           57.2
# 4    United Arab Emirates         ARE     11.044           88.0
# ..                    ...         ...        ...            ...
# 190           Yemen, Rep.         YEM     32.947           20.0
# 191          South Africa         ZAF     20.850           46.5
# 192      Congo, Dem. Rep.         COD     42.394            2.2
# 193                Zambia         ZMB     40.471           15.4
# 194              Zimbabwe         ZWE     35.715           18.5
#
#              IncomeGroup
# 0            High income
# 1             Low income
# 2    Upper middle income
# 3    Upper middle income
# 4            High income
# ..                   ...
# ...

# %%
stats[::20]
# print rows at every 20 interval
# means print every 20th row
# Out:
#     CountryName CountryCode  BirthRate  InternetUsers          IncomeGroup
# 0         Aruba         ABW     10.244        78.9000          High income
# 20      Belarus         BLR     12.500        54.1700  Upper middle income
# 40   Costa Rica         CRI     15.022        45.9600  Upper middle income
# 60        Gabon         GAB     30.555         9.2000  Upper middle income
# 80        India         IND     20.291        15.1000  Lower middle income
# 100       Libya         LBY     21.425        16.5000  Upper middle income
# 120  Mozambique         MOZ     39.705         5.4000           Low income
# 140      Poland         POL      9.600        62.8492          High income
# 160    Suriname         SUR     18.455        37.4000  Upper middle income
# 180     Uruguay         URY     14.374        57.6900          High income

# %%
stats.columns
# Out:
# Index(['CountryName', 'CountryCode', 'BirthRate', 'InternetUsers',
#        'IncomeGroup'],
#       dtype='object')

# %%
stats.head()
# Out:
#             CountryName CountryCode  BirthRate  InternetUsers  \
# 0                 Aruba         ABW     10.244           78.9
# 1           Afghanistan         AFG     35.253            5.9
# 2                Angola         AGO     45.985           19.1
# 3               Albania         ALB     12.877           57.2
# 4  United Arab Emirates         ARE     11.044           88.0
#
#            IncomeGroup
# 0          High income
# 1           Low income
# 2  Upper middle income
# 3  Upper middle income
# 4          High income

# %%
stats['CountryName'].head()
# print countryname column top 5 rows
# pls remind some columns name is case sensetive so chances of error increases
# so be carefull about case sensetive error
# Out:
# 0                   Aruba
# 1             Afghanistan
# 2                  Angola
# 3                 Albania
# 4    United Arab Emirates
# Name: CountryName, dtype: object

# %%
['CountryName', 'CountryCode']
# Out:
# ['CountryName', 'CountryCode']

# %%
stats[['CountryName', 'CountryCode']].head()
# print CountryName & CountryCode columns top 5 rows
# Out:
#             CountryName CountryCode
# 0                 Aruba         ABW
# 1           Afghanistan         AFG
# 2                Angola         AGO
# 3               Albania         ALB
# 4  United Arab Emirates         ARE

# %%
stats.head()
# Out:
#             CountryName CountryCode  BirthRate  InternetUsers  \
# 0                 Aruba         ABW     10.244           78.9
# 1           Afghanistan         AFG     35.253            5.9
# 2                Angola         AGO     45.985           19.1
# 3               Albania         ALB     12.877           57.2
# 4  United Arab Emirates         ARE     11.044           88.0
#
#            IncomeGroup
# 0          High income
# 1           Low income
# 2  Upper middle income
# 3  Upper middle income
# 4          High income

# %%
stats['BirthRate']
# print birthrate column
# Out:
# 0      10.244
# 1      35.253
# 2      45.985
# 3      12.877
# 4      11.044
#         ...
# 190    32.947
# 191    20.850
# 192    42.394
# 193    40.471
# 194    35.715
# Name: BirthRate, Length: 195, dtype: float64

# %%
# combine the two
stats[14:32][['CountryName', 'CountryCode']]
# print 14 to 31 rows (n-1) of CountryName & CountryCode column
# Out:
#                  CountryName CountryCode
# 14              Burkina Faso         BFA
# 15                Bangladesh         BGD
# 16                  Bulgaria         BGR
# 17                   Bahrain         BHR
# 18              Bahamas, The         BHS
# 19    Bosnia and Herzegovina         BIH
# 20                   Belarus         BLR
# 21                    Belize         BLZ
# 22                   Bermuda         BMU
# 23                   Bolivia         BOL
# 24                    Brazil         BRA
# 25                  Barbados         BRB
# 26         Brunei Darussalam         BRN
# 27                    Bhutan         BTN
# 28                  Botswana         BWA
# 29  Central African Republic         CAF
# 30                    Canada         CAN
# 31               Switzerland         CHE

# %%
stats[['CountryName', 'CountryCode']][14:32]
# same output as above
# Out:
#                  CountryName CountryCode
# 14              Burkina Faso         BFA
# 15                Bangladesh         BGD
# 16                  Bulgaria         BGR
# 17                   Bahrain         BHR
# 18              Bahamas, The         BHS
# 19    Bosnia and Herzegovina         BIH
# 20                   Belarus         BLR
# 21                    Belize         BLZ
# 22                   Bermuda         BMU
# 23                   Bolivia         BOL
# 24                    Brazil         BRA
# 25                  Barbados         BRB
# 26         Brunei Darussalam         BRN
# 27                    Bhutan         BTN
# 28                  Botswana         BWA
# 29  Central African Republic         CAF
# 30                    Canada         CAN
# 31               Switzerland         CHE

# %%
stats.columns
# Out:
# Index(['CountryName', 'CountryCode', 'BirthRate', 'InternetUsers',
#        'IncomeGroup'],
#       dtype='object')

# %%
stats[['CountryName', 'CountryCode', 'BirthRate', 'InternetUsers',
       'IncomeGroup']][12:54]
# print mentioned columns 12 to 53 (n-1)
# print mentioned (all columns)
# Out:
#                  CountryName CountryCode  BirthRate  InternetUsers  \
# 12                   Belgium         BEL     11.200      82.170200
# 13                     Benin         BEN     36.440       4.900000
# 14              Burkina Faso         BFA     40.551       9.100000
# 15                Bangladesh         BGD     20.142       6.630000
# 16                  Bulgaria         BGR      9.200      53.061500
# 17                   Bahrain         BHR     15.040      90.000040
# 18              Bahamas, The         BHS     15.339      72.000000
# 19    Bosnia and Herzegovina         BIH      9.062      57.790000
# 20                   Belarus         BLR     12.500      54.170000
# 21                    Belize         BLZ     23.092      33.600000
# 22                   Bermuda         BMU     10.400      95.300000
# 23                   Bolivia         BOL     24.236      36.940000
# 24                    Brazil         BRA     14.931      51.040000
# ...

# %%
stats[['CountryName', 'CountryCode', 'BirthRate']][33:154]
# print countryname, countrycode & bithrate columns 33 to 153 (n-1)
# Out:
#          CountryName CountryCode  BirthRate
# 33             China         CHN     12.100
# 34     Cote d'Ivoire         CIV     37.320
# 35          Cameroon         CMR     37.236
# 36       Congo, Rep.         COG     37.011
# 37          Colombia         COL     16.076
# ..               ...         ...        ...
# 149     Saudi Arabia         SAU     20.576
# 150            Sudan         SDN     33.477
# 151          Senegal         SEN     38.533
# 152        Singapore         SGP      9.300
# 153  Solomon Islands         SLB     30.578
#
# [121 rows x 3 columns]

# %%
stats.head()
# Out:
#             CountryName CountryCode  BirthRate  InternetUsers  \
# 0                 Aruba         ABW     10.244           78.9
# 1           Afghanistan         AFG     35.253            5.9
# 2                Angola         AGO     45.985           19.1
# 3               Albania         ALB     12.877           57.2
# 4  United Arab Emirates         ARE     11.044           88.0
#
#            IncomeGroup
# 0          High income
# 1           Low income
# 2  Upper middle income
# 3  Upper middle income
# 4          High income

# %%
stats. BirthRate * stats.InternetUsers
# bithrate col * internetusers col
# print bithrate * internetusers
# Out:
# 0      808.2516
# 1      207.9927
# 2      878.3135
# 3      736.5644
# 4      971.8720
#          ...
# 190    658.9400
# 191    969.5250
# 192     93.2668
# 193    623.2534
# 194    660.7275
# Length: 195, dtype: float64

# %%
# add a columns
stats['result']=stats.BirthRate * stats.InternetUsers
# add another column of bithrate * internetusers result
stats.head()
# Out:
#             CountryName CountryCode  BirthRate  InternetUsers  \
# 0                 Aruba         ABW     10.244           78.9
# 1           Afghanistan         AFG     35.253            5.9
# 2                Angola         AGO     45.985           19.1
# 3               Albania         ALB     12.877           57.2
# 4  United Arab Emirates         ARE     11.044           88.0
#
#            IncomeGroup    result
# 0          High income  808.2516
# 1           Low income  207.9927
# 2  Upper middle income  878.3135
# 3  Upper middle income  736.5644
# 4          High income  971.8720

# %%
stats
# see the result column are added now
# Out:
#               CountryName CountryCode  BirthRate  InternetUsers  \
# 0                   Aruba         ABW     10.244           78.9
# 1             Afghanistan         AFG     35.253            5.9
# 2                  Angola         AGO     45.985           19.1
# 3                 Albania         ALB     12.877           57.2
# 4    United Arab Emirates         ARE     11.044           88.0
# ..                    ...         ...        ...            ...
# 190           Yemen, Rep.         YEM     32.947           20.0
# 191          South Africa         ZAF     20.850           46.5
# 192      Congo, Dem. Rep.         COD     42.394            2.2
# 193                Zambia         ZMB     40.471           15.4
# 194              Zimbabwe         ZWE     35.715           18.5
#
#              IncomeGroup    result
# 0            High income  808.2516
# 1             Low income  207.9927
# 2    Upper middle income  878.3135
# 3    Upper middle income  736.5644
# ...

# %%
# delete the column || remove the column
stats.drop('result', axis=1)
# remove the column
# drop should be use for remove the column
# Out:
#               CountryName CountryCode  BirthRate  InternetUsers  \
# 0                   Aruba         ABW     10.244           78.9
# 1             Afghanistan         AFG     35.253            5.9
# 2                  Angola         AGO     45.985           19.1
# 3                 Albania         ALB     12.877           57.2
# 4    United Arab Emirates         ARE     11.044           88.0
# ..                    ...         ...        ...            ...
# 190           Yemen, Rep.         YEM     32.947           20.0
# 191          South Africa         ZAF     20.850           46.5
# 192      Congo, Dem. Rep.         COD     42.394            2.2
# 193                Zambia         ZMB     40.471           15.4
# 194              Zimbabwe         ZWE     35.715           18.5
#
#              IncomeGroup
# 0            High income
# 1             Low income
# 2    Upper middle income
# 3    Upper middle income
# 4            High income
# ..                   ...
# ...

# %%
stats.head()
# Out:
#             CountryName CountryCode  BirthRate  InternetUsers  \
# 0                 Aruba         ABW     10.244           78.9
# 1           Afghanistan         AFG     35.253            5.9
# 2                Angola         AGO     45.985           19.1
# 3               Albania         ALB     12.877           57.2
# 4  United Arab Emirates         ARE     11.044           88.0
#
#            IncomeGroup    result
# 0          High income  808.2516
# 1           Low income  207.9927
# 2  Upper middle income  878.3135
# 3  Upper middle income  736.5644
# 4          High income  971.8720

# %%
stats.head(26)
# Out:
#                CountryName CountryCode  BirthRate  InternetUsers  \
# 0                    Aruba         ABW     10.244       78.90000
# 1              Afghanistan         AFG     35.253        5.90000
# 2                   Angola         AGO     45.985       19.10000
# 3                  Albania         ALB     12.877       57.20000
# 4     United Arab Emirates         ARE     11.044       88.00000
# 5                Argentina         ARG     17.716       59.90000
# 6                  Armenia         ARM     13.308       41.90000
# 7      Antigua and Barbuda         ATG     16.447       63.40000
# 8                Australia         AUS     13.200       83.00000
# 9                  Austria         AUT      9.400       80.61880
# 10              Azerbaijan         AZE     18.300       58.70000
# 11                 Burundi         BDI     44.151        1.30000
# 12                 Belgium         BEL     11.200       82.17020
# ...

# %%
stats.columns[2]
# Out:
# 'BirthRate'

# %%
stats[0:27].InternetUsers<2
# it will check internetusers colmns condition which is less than 2 or not
# we are checking of given condition 
# if its correct output will be True 
# if its incorect output will be False
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11     True
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# 21    False
# 22    False
# 23    False
# 24    False
# 25    False
# 26    False
# Name: InternetUsers, dtype: bool

# %%
filter= stats.InternetUsers < 2

# %%
stats[filter]
# print only thos columns that internetusers will be less than 2
# & here will be 9 columns having internetusers having less than 2 (<2)
# Out:
#       CountryName CountryCode  BirthRate  InternetUsers          IncomeGroup  \
# 11        Burundi         BDI     44.151            1.3           Low income
# 52        Eritrea         ERI     34.800            0.9           Low income
# 55       Ethiopia         ETH     32.925            1.9           Low income
# 64         Guinea         GIN     37.337            1.6           Low income
# 117       Myanmar         MMR     18.119            1.6  Lower middle income
# 127         Niger         NER     49.661            1.7           Low income
# 154  Sierra Leone         SLE     36.729            1.7           Low income
# 156       Somalia         SOM     43.891            1.5           Low income
# 172   Timor-Leste         TLS     35.755            1.1  Lower middle income
#
#       result
# 11   57.3963
# 52   31.3200
# 55   62.5575
# 64   59.7392
# 117  28.9904
# 127  84.4237
# 154  62.4393
# 156  65.8365
# 172  39.3305

# %%
stats.BirthRate > 40
# print True & False columns as per given condition
# Out:
# 0      False
# 1      False
# 2       True
# 3      False
# 4      False
#        ...
# 190    False
# 191    False
# 192     True
# 193     True
# 194    False
# Name: BirthRate, Length: 195, dtype: bool

# %%
filter2 = stats.BirthRate > 40

# %%
stats[filter2]
# print only those columns having bithrate more than 40
# Out:
#           CountryName CountryCode  BirthRate  InternetUsers  \
# 2              Angola         AGO     45.985           19.1
# 11            Burundi         BDI     44.151            1.3
# 14       Burkina Faso         BFA     40.551            9.1
# 65        Gambia, The         GMB     42.525           14.0
# 115              Mali         MLI     44.138            3.5
# 127             Niger         NER     49.661            1.7
# 128           Nigeria         NGA     40.045           38.0
# 156           Somalia         SOM     43.891            1.5
# 167              Chad         TCD     45.745            2.3
# 178            Uganda         UGA     43.474           16.2
# 192  Congo, Dem. Rep.         COD     42.394            2.2
# 193            Zambia         ZMB     40.471           15.4
#
#              IncomeGroup     result
# 2    Upper middle income   878.3135
# 11            Low income    57.3963
# 14            Low income   369.0141
# ...

# %%
filter2
# Out:
# 0      False
# 1      False
# 2       True
# 3      False
# 4      False
#        ...
# 190    False
# 191    False
# 192     True
# 193     True
# 194    False
# Name: BirthRate, Length: 195, dtype: bool

# %%
stats[filter2]
# Out:
#           CountryName CountryCode  BirthRate  InternetUsers  \
# 2              Angola         AGO     45.985           19.1
# 11            Burundi         BDI     44.151            1.3
# 14       Burkina Faso         BFA     40.551            9.1
# 65        Gambia, The         GMB     42.525           14.0
# 115              Mali         MLI     44.138            3.5
# 127             Niger         NER     49.661            1.7
# 128           Nigeria         NGA     40.045           38.0
# 156           Somalia         SOM     43.891            1.5
# 167              Chad         TCD     45.745            2.3
# 178            Uganda         UGA     43.474           16.2
# 192  Congo, Dem. Rep.         COD     42.394            2.2
# 193            Zambia         ZMB     40.471           15.4
#
#              IncomeGroup     result
# 2    Upper middle income   878.3135
# 11            Low income    57.3963
# 14            Low income   369.0141
# ...

# %%
stats[filter & filter2]
# print whichever condition is True 
# use of & operartor
# Out:
#     CountryName CountryCode  BirthRate  InternetUsers IncomeGroup   result
# 11      Burundi         BDI     44.151            1.3  Low income  57.3963
# 127       Niger         NER     49.661            1.7  Low income  84.4237
# 156     Somalia         SOM     43.891            1.5  Low income  65.8365

# %%
stats[(stats.BirthRate > 40) & (stats.InternetUsers <2)]
# use of & operator 
# whicjever is True that will be printed
# Out:
#     CountryName CountryCode  BirthRate  InternetUsers IncomeGroup   result
# 11      Burundi         BDI     44.151            1.3  Low income  57.3963
# 127       Niger         NER     49.661            1.7  Low income  84.4237
# 156     Somalia         SOM     43.891            1.5  Low income  65.8365

# %%
stats.head()
# Out:
#             CountryName CountryCode  BirthRate  InternetUsers  \
# 0                 Aruba         ABW     10.244           78.9
# 1           Afghanistan         AFG     35.253            5.9
# 2                Angola         AGO     45.985           19.1
# 3               Albania         ALB     12.877           57.2
# 4  United Arab Emirates         ARE     11.044           88.0
#
#            IncomeGroup    result
# 0          High income  808.2516
# 1           Low income  207.9927
# 2  Upper middle income  878.3135
# 3  Upper middle income  736.5644
# 4          High income  971.8720

# %%
stats
# Out:
#               CountryName CountryCode  BirthRate  InternetUsers  \
# 0                   Aruba         ABW     10.244           78.9
# 1             Afghanistan         AFG     35.253            5.9
# 2                  Angola         AGO     45.985           19.1
# 3                 Albania         ALB     12.877           57.2
# 4    United Arab Emirates         ARE     11.044           88.0
# ..                    ...         ...        ...            ...
# 190           Yemen, Rep.         YEM     32.947           20.0
# 191          South Africa         ZAF     20.850           46.5
# 192      Congo, Dem. Rep.         COD     42.394            2.2
# 193                Zambia         ZMB     40.471           15.4
# 194              Zimbabwe         ZWE     35.715           18.5
#
#              IncomeGroup    result
# 0            High income  808.2516
# 1             Low income  207.9927
# 2    Upper middle income  878.3135
# 3    Upper middle income  736.5644
# ...

# %%
stats[stats.IncomeGroup == 'Low income']
# print income=low income group
# print only icomegroup having low income
# Out:
#                   CountryName CountryCode  BirthRate  InternetUsers  \
# 1                 Afghanistan         AFG     35.253           5.90
# 11                    Burundi         BDI     44.151           1.30
# 13                      Benin         BEN     36.440           4.90
# 14               Burkina Faso         BFA     40.551           9.10
# 29   Central African Republic         CAF     34.076           3.50
# 38                    Comoros         COM     34.326           6.50
# 52                    Eritrea         ERI     34.800           0.90
# 55                   Ethiopia         ETH     32.925           1.90
# 64                     Guinea         GIN     37.337           1.60
# 65                Gambia, The         GMB     42.525          14.00
# 66              Guinea-Bissau         GNB     37.503           3.10
# 77                      Haiti         HTI     25.345          10.60
# 93                   Cambodia         KHM     24.462           6.80
# ...

# %%
# how to get the unique categories

# %%
stats.IncomeGroup.unique()
# print income categories as we mentioned in the incomegroup
# High income, Low income, Upper middle income, Lower middle income 
# are mentioned in the income group
# unique function help to print categories of that perticular column
# that all categories we mentioned in data set
# Out:
# array(['High income', 'Low income', 'Upper middle income',
#        'Lower middle income'], dtype=object)

# %%
stats.IncomeGroup.unique()
# Out:
# array(['High income', 'Low income', 'Upper middle income',
#        'Lower middle income'], dtype=object)

# %%
# introduction of seaborn # seaborn is very powerful visualization package
# staticstics visualization
import matplotlib.pyplot as plt   #  visualization
import seaborn as sns    # distribution  visualization
# %matplotlib inline 
import warnings
warnings.filterwarnings('ignore',category=DeprecationWarning)

# %%
stats.head()
# Out:
#             CountryName CountryCode  BirthRate  InternetUsers  \
# 0                 Aruba         ABW     10.244           78.9
# 1           Afghanistan         AFG     35.253            5.9
# 2                Angola         AGO     45.985           19.1
# 3               Albania         ALB     12.877           57.2
# 4  United Arab Emirates         ARE     11.044           88.0
#
#            IncomeGroup    result
# 0          High income  808.2516
# 1           Low income  207.9927
# 2  Upper middle income  878.3135
# 3  Upper middle income  736.5644
# 4          High income  971.8720

# %%
stats.columns
# Out:
# Index(['CountryName', 'CountryCode', 'BirthRate', 'InternetUsers',
#        'IncomeGroup', 'result'],
#       dtype='object')

# %%
# Distributions: 
vis1 = sns.distplot(stats["InternetUsers"])
# Out:
# C:\Users\yogesh khairnar\AppData\Local\Temp\ipykernel_1656\2094964690.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   vis1 = sns.distplot(stats["InternetUsers"])

# %%
vi=sns.displot(stats["InternetUsers"], bins=10)

# %%
# box plot
vis2=sns.boxplot(data=stats, x='IncomeGroup', y='BirthRate')

# %%
# refer seaborn library

# %%
# visualization with seaborn

# %%
vis3=sns.lmplot(data=stats,x='InternetUsers', y='BirthRate', fit_reg=False)   # lm--> linear model
# lm=linerar model
# fit

# %%
vis4=sns.lmplot(data=stats, x='InternetUsers', y='BirthRate')

# %%
vi5=sns.lmplot(data=stats, x='InternetUsers', y='BirthRate', fit_reg=False, hue='IncomeGroup')
# hue --> parameter for colour

# %%
vis5 = sns.lmplot(data = stats,x = 'InternetUsers', y = 'BirthRate',
                  fit_reg = False,hue = 'IncomeGroup')

# %%
# !pip install seaborn
