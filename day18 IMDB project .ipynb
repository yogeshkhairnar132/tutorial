# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # IMDB ratings analysis

# %%
import pandas as pd

# %%
movies=pd.read_csv(r"E:\Data Science\senapati\day19 IMDB project -3\archive\movie.csv")
movies.shape
# copy the movies file path (IMDB file --> movies file)
# r is important it's meaaning is read
# r menas read the file
# r use before the path may bring the file in reading mode
# Out:
# (27278, 3)

# %%
movies.head()
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy

# %%
movies.head(116)
# print top 115 rows (n-1)
# Out:
#      movieId                                              title  \
# 0          1                                   Toy Story (1995)
# 1          2                                     Jumanji (1995)
# 2          3                            Grumpier Old Men (1995)
# 3          4                           Waiting to Exhale (1995)
# 4          5                 Father of the Bride Part II (1995)
# ..       ...                                                ...
# 111      113                            Before and After (1996)
# 112      114                           Margaret's Museum (1995)
# 113      115  Happiness Is in the Field (Bonheur est dans le...
# 114      116                       Anne Frank Remembered (1995)
# 115      117              Young Poisoner's Handbook, The (1995)
#
#                                           genres
# 0    Adventure|Animation|Children|Comedy|Fantasy
# 1                     Adventure|Children|Fantasy
# ...

# %%
movies.tail()
# print bottom 5 rows
# Out:
#        movieId                          title                    genres
# 27273   131254   Kein Bund für's Leben (2007)                    Comedy
# 27274   131256  Feuer, Eis & Dosenbier (2002)                    Comedy
# 27275   131258             The Pirates (2014)                 Adventure
# 27276   131260            Rentun Ruusu (2001)        (no genres listed)
# 27277   131262               Innocence (2014)  Adventure|Fantasy|Horror

# %%
movies.tail(23546)
# print last 23545 rows (n-1)
# Out:
#        movieId                          title                          genres
# 3732      3824      Autumn in New York (2000)                   Drama|Romance
# 3733      3825             Coyote Ugly (2000)            Comedy|Drama|Romance
# 3734      3826              Hollow Man (2000)          Horror|Sci-Fi|Thriller
# 3735      3827           Space Cowboys (2000)  Action|Adventure|Comedy|Sci-Fi
# 3736      3828           Better Living (1998)                          Comedy
# ...        ...                            ...                             ...
# 27273   131254   Kein Bund für's Leben (2007)                          Comedy
# 27274   131256  Feuer, Eis & Dosenbier (2002)                          Comedy
# 27275   131258             The Pirates (2014)                       Adventure
# 27276   131260            Rentun Ruusu (2001)              (no genres listed)
# 27277   131262               Innocence (2014)        Adventure|Fantasy|Horror
#
# [23546 rows x 3 columns]

# %%
movies = pd.read_csv(r"E:\Data Science\senapati\day19 IMDB project -3\archive\movie.csv", sep=',')
movies.head()
#  sep=',' ----> gives same output as above there is no need of all parameter
# to mentioned just keep it compact & easy to understand in simple way
#  sep=','---> is coma separated file
# it printed as it is movies.head()----> top 5 rows
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy

# %%
movies = pd.read_csv(r"E:\Data Science\senapati\day19 IMDB project -3\archive\movie.csv", sep=',')
movies.head(15546)
# print top 15545 row  (n-1)
# there is no need of sep=','
# it gives same output
# Out:
#        movieId                               title  \
# 0            1                    Toy Story (1995)
# 1            2                      Jumanji (1995)
# 2            3             Grumpier Old Men (1995)
# 3            4            Waiting to Exhale (1995)
# 4            5  Father of the Bride Part II (1995)
# ...        ...                                 ...
# 15541    79185               Knight and Day (2010)
# 15542    79187                Greatest, The (2009)
# 15543    79191                   Roadracers (1994)
# 15544    79195                     Raincoat (2004)
# 15545    79197       Fastest Gun Alive, The (1956)
#
#                                             genres
# 0      Adventure|Animation|Children|Comedy|Fantasy
# 1                       Adventure|Children|Fantasy
# 2                                   Comedy|Romance
# 3                             Comedy|Drama|Romance
# 4                                           Comedy
# ...

# %%
ratings=pd.read_csv(r"E:\Data Science\senapati\day19 IMDB project -3\archive\rating.csv")
ratings.shape
# please remembered to type r  (r--> read (before file path))
# copy the rating file path (IMDB file --> rating file)
# Out:
# (20000263, 4)

# %% [markdown]
# - there are 2 crores rows in python just see above this cell
# - excel have only 1048000 rows (excel has limited rocordrecords as compared to python

# %%
ratings
# Out:
#           userId  movieId  rating            timestamp
# 0              1        2     3.5  2005-04-02 23:53:47
# 1              1       29     3.5  2005-04-02 23:31:16
# 2              1       32     3.5  2005-04-02 23:33:39
# 3              1       47     3.5  2005-04-02 23:32:07
# 4              1       50     3.5  2005-04-02 23:29:40
# ...          ...      ...     ...                  ...
# 20000258  138493    68954     4.5  2009-11-13 15:42:00
# 20000259  138493    69526     4.5  2009-12-03 18:31:48
# 20000260  138493    69644     3.0  2009-12-07 18:10:57
# 20000261  138493    70286     5.0  2009-11-13 15:42:24
# 20000262  138493    71619     2.5  2009-10-17 20:25:36
#
# [20000263 rows x 4 columns]

# %%
ratings.head(1000000)
# print top 1000000 rows
# Out:
#         userId  movieId  rating            timestamp
# 0            1        2     3.5  2005-04-02 23:53:47
# 1            1       29     3.5  2005-04-02 23:31:16
# 2            1       32     3.5  2005-04-02 23:33:39
# 3            1       47     3.5  2005-04-02 23:32:07
# 4            1       50     3.5  2005-04-02 23:29:40
# ...        ...      ...     ...                  ...
# 999995    6743     1580     4.0  2005-06-03 01:05:57
# 999996    6743     1584     3.0  2005-06-03 01:09:03
# 999997    6743     1586     3.0  2005-06-03 01:23:51
# 999998    6743     1589     4.0  2005-06-03 01:26:30
# 999999    6743     1590     4.0  2005-06-03 01:25:13
#
# [1000000 rows x 4 columns]

# %%
tags=pd.read_csv(r"E:\Data Science\senapati\day19 IMDB project -3\archive\tag.csv")
tags.shape
# print rows & columns
# Out:
# (465564, 4)

# %%
tags.head()
# print top 5 rows by default
# Out:
#    userId  movieId            tag            timestamp
# 0      18     4141    Mark Waters  2009-04-24 18:19:40
# 1      65      208      dark hero  2013-05-10 01:41:18
# 2      65      353      dark hero  2013-05-10 01:41:19
# 3      65      521  noir thriller  2013-05-10 01:39:43
# 4      65      592      dark hero  2013-05-10 01:41:18

# %%
tags.head(22000)
# Out:
#        userId  movieId               tag            timestamp
# 0          18     4141       Mark Waters  2009-04-24 18:19:40
# 1          65      208         dark hero  2013-05-10 01:41:18
# 2          65      353         dark hero  2013-05-10 01:41:19
# 3          65      521     noir thriller  2013-05-10 01:39:43
# 4          65      592         dark hero  2013-05-10 01:41:18
# ...       ...      ...               ...                  ...
# 21995    4450   110968  natural disaster  2014-06-01 01:36:54
# 21996    4450   110968           volcano  2014-06-01 01:36:57
# 21997    4450   111659    Angelina Jolie  2015-01-05 16:08:42
# 21998    4450   111659          betrayal  2015-01-05 16:09:24
# 21999    4450   111659            Disney  2015-01-05 16:09:14
#
# [22000 rows x 4 columns]

# %%
tags.tail(24569)
# Out:
#         userId  movieId                         tag            timestamp
# 440995  130827    26954               Nudity (Rear)  2009-07-21 16:28:57
# 440996  130827    26954  Nudity (Topless - Notable)  2009-07-21 16:28:42
# 440997  130827    26954                      sexual  2009-07-21 16:28:14
# 440998  130827    26954                     village  2009-07-21 16:33:31
# 440999  130827    26954                        wine  2009-07-21 17:22:49
# ...        ...      ...                         ...                  ...
# 465559  138446    55999                     dragged  2013-01-23 23:29:32
# 465560  138446    55999               Jason Bateman  2013-01-23 23:29:38
# 465561  138446    55999                      quirky  2013-01-23 23:29:38
# 465562  138446    55999                         sad  2013-01-23 23:29:32
# 465563  138472      923               rise to power  2007-11-02 21:12:47
#
# [24569 rows x 4 columns]

# %% [markdown]
# # data structure
# ### series

# %%
row_155 = tags.iloc[155]    
type(row_0)
#print oth row elements (print oth row columns elements)
# Out:
# pandas.core.series.Series

# %%
row_155
# print oth row elements (print oth row columns elements)
# row 155 is actually row 157 bcz
# 1st row having columns name &
# 2nd row having start from 1st row
# hence it is now n+2
# Out:
# userId                       129
# movieId                     4878
# tag           alternate timeline
# timestamp    2011-04-04 03:10:44
# Name: 155, dtype: object

# %%
row_155.index
# Out:
# Index(['userId', 'movieId', 'tag', 'timestamp'], dtype='object')

# %%
row_155['tag']
# in excel file there is tag column (not tags)
# tags is the variable we are created & tag are column in data set
# Out:
# 'alternate timeline'

# %%
'rating' in row_155
# check there is rating are column are peresent are not
# Out:
# False

# %%
row_155.name
# row name is 155
# Out:
# 155

# %%
row_155=row_155.rename('row_157')

# %%
row_155.name
# rename the row of row_155---> to row_157
# Out:
# 'row_157'

# %% [markdown]
# # data frames

# %%
tags.head()
# Out:
#    userId  movieId            tag            timestamp
# 0      18     4141    Mark Waters  2009-04-24 18:19:40
# 1      65      208      dark hero  2013-05-10 01:41:18
# 2      65      353      dark hero  2013-05-10 01:41:19
# 3      65      521  noir thriller  2013-05-10 01:39:43
# 4      65      592      dark hero  2013-05-10 01:41:18

# %%
tags.index
# it gives start index, stop index & step index
# Out:
# RangeIndex(start=0, stop=465564, step=1)

# %%
tags.columns
# Out:
# Index(['userId', 'movieId', 'tag', 'timestamp'], dtype='object')

# %%
tags.iloc[[0,154,283]]
# print 0th, 156th  & 285rd row
# bcz n+2 # bcz oth row are columns name & 2nd row have 1st row
# Out:
#      userId  movieId          tag            timestamp
# 0        18     4141  Mark Waters  2009-04-24 18:19:40
# 154     129     4732    stupid :)  2011-02-08 05:56:32
# 283     279      916    slapstick  2012-02-23 02:01:35

# %% [markdown]
# # descriptive statistic
# #### let's  look how the ratings are distributed

# %%
ratings['rating'].describe()
# use describe function
# which gives statistical analysis of
# Out:
# count    2.000026e+07
# mean     3.525529e+00
# std      1.051989e+00
# min      5.000000e-01
# 25%      3.000000e+00
# 50%      3.500000e+00
# 75%      4.000000e+00
# max      5.000000e+00
# Name: rating, dtype: float64

# %%
ratings.describe()
# Out:
#              userId       movieId        rating
# count  2.000026e+07  2.000026e+07  2.000026e+07
# mean   6.904587e+04  9.041567e+03  3.525529e+00
# std    4.003863e+04  1.978948e+04  1.051989e+00
# min    1.000000e+00  1.000000e+00  5.000000e-01
# 25%    3.439500e+04  9.020000e+02  3.000000e+00
# 50%    6.914100e+04  2.167000e+03  3.500000e+00
# 75%    1.036370e+05  4.770000e+03  4.000000e+00
# max    1.384930e+05  1.312620e+05  5.000000e+00

# %%
ratings['rating'].mean()
# it gives mean og rating column in the data set
# Out:
# 3.5255285642993797

# %%
ratings['rating'].min()
# it gives min. value of rating column in the data set
# Out:
# 0.5

# %%
ratings['rating'].std()
# it print standard deviation of rating column in the data set
# Out:
# 1.051988919275684

# %%
ratings['rating']. mode()
# print mode of hte rating column
# Out:
# 0    4.0
# Name: rating, dtype: float64

# %%
ratings.corr()
# it will be helpful in machine learing 
# just note down 
# 1= +ve strong reletionship  & 
# -1 = -ve strong reletipnship
# Out:
# C:\Users\yogesh khairnar\AppData\Local\Temp\ipykernel_19372\1862968945.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   ratings.corr()
#            userId   movieId    rating
# userId   1.000000 -0.000850  0.001175
# movieId -0.000850  1.000000  0.002606
# rating   0.001175  0.002606  1.000000

# %%
filter=ratings['rating']>4
# check if greater--> True  & lower---> False

# %%
filter
# Out:
# 0           False
# 1           False
# 2           False
# 3           False
# 4           False
#             ...
# 20000258     True
# 20000259     True
# 20000260    False
# 20000261     True
# 20000262    False
# Name: rating, Length: 20000263, dtype: bool

# %%
filter2=ratings['rating']<4.5

# %%
filter2
# Out:
# 0            True
# 1            True
# 2            True
# 3            True
# 4            True
#             ...
# 20000258    False
# 20000259    False
# 20000260     True
# 20000261    False
# 20000262     True
# Name: rating, Length: 20000263, dtype: bool

# %% [markdown]
# # data cleaning

# %%
movies.shape
# it gives rows & columns
# Out:
# (27278, 3)

# %%
movies.isnull().any().any()
# that means no null value in movies data set
# Out:
# False

# %%
ratings.shape
# Out:
# (20000263, 4)

# %%
ratings.isnull().any().any()
# checck if any null values 
# & gives output as True or False
# Out:
# False

# %%
tags.shape
# Out:
# (465564, 4)

# %%
tags.isnull().any().any()
# Out:
# True

# %%
tags.isnull()
# check that any null value in whole data set
# Out:
#         userId  movieId    tag  timestamp
# 0        False    False  False      False
# 1        False    False  False      False
# 2        False    False  False      False
# 3        False    False  False      False
# 4        False    False  False      False
# ...        ...      ...    ...        ...
# 465559   False    False  False      False
# 465560   False    False  False      False
# 465561   False    False  False      False
# 465562   False    False  False      False
# 465563   False    False  False      False
#
# [465564 rows x 4 columns]

# %%
tags.isnull().any()
# check that any null value in columns
# tag column have null value hence it output is in True
# Out:
# userId       False
# movieId      False
# tag           True
# timestamp    False
# dtype: bool

# %%
tags.isnull().any().any()
# check that is any null value in whole data set
# there is null value in tag column
# hence the uotput is True
# Out:
# True

# %%
tags=tags.dropna()
# here .dropna() function are removed those rows having null value
# main difference between isnull().any().any()  vs .dropna()  is
# isnull().any().any()-----> shows output in True or false
# .dropna()----> it delete or remove the row has null value

# %%
tags.isnull().any().any()
# see now output is False
# .drpna() fucntion delete the row having null value & output will be change
# Out:
# False

# %%
tags.shape
# Out:
# (465548, 4)

# %% [markdown]
# # data visualization

# %%
# %matplotlib inline

# %%
ratings.hist(column='rating', figsize=(8,5))
# column='rating': This specifies that we want to create 
# the histogram for the 'rating' column in the dataframe.
# Out:
# array([[<Axes: title={'center': 'rating'}>]], dtype=object)

# %%
ratings.boxplot(column='rating', figsize=(10,5))
# Out:
# <Axes: >

# %% [markdown]
# # slicing out columns

# %%
tags['tag'].head()
# print top 5 rows of tag column
# Out:
# 0      Mark Waters
# 1        dark hero
# 2        dark hero
# 3    noir thriller
# 4        dark hero
# Name: tag, dtype: object

# %%
movies[['title','genres']].head()
# print both title & genres columns 5 rows
# Out:
#                                 title  \
# 0                    Toy Story (1995)
# 1                      Jumanji (1995)
# 2             Grumpier Old Men (1995)
# 3            Waiting to Exhale (1995)
# 4  Father of the Bride Part II (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy

# %%
ratings[-10:]
# print last 10 rpws of rating columns
# Out:
#           userId  movieId  rating            timestamp
# 20000253  138493    60816     4.5  2009-12-03 18:32:43
# 20000254  138493    61160     4.0  2009-11-16 16:55:37
# 20000255  138493    65682     4.5  2009-10-17 21:52:53
# 20000256  138493    66762     4.5  2009-10-17 18:50:08
# 20000257  138493    68319     4.5  2009-12-07 18:15:20
# 20000258  138493    68954     4.5  2009-11-13 15:42:00
# 20000259  138493    69526     4.5  2009-12-03 18:31:48
# 20000260  138493    69644     3.0  2009-12-07 18:10:57
# 20000261  138493    70286     5.0  2009-11-13 15:42:24
# 20000262  138493    71619     2.5  2009-10-17 20:25:36

# %%
tag_counts=tags['tag'].value_counts()
tag_counts[-10:]
# count the value in tag column in last 10 elements in tag column
# value_counts(): This method counts the frequency of each 
# unique value in the specified column and 
# returns a Series with the counts.
# Out:
# missing child                    1
# Ron Moore                        1
# Citizen Kane                     1
# mullet                           1
# biker gang                       1
# Paul Adelstein                   1
# the wig                          1
# killer fish                      1
# genetically modified monsters    1
# topless scene                    1
# Name: tag, dtype: int64

# %%
tag_counts[:10].plot(kind='bar',figsize=(10,5))
# Out:
# <Axes: >
