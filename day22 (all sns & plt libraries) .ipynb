# %%
# !pip install seaborn --upgrade

# %%
import pandas as pd

# %%
movies=pd.read_csv(r"E:\Data Science\senapati\day22\New folder\Movie-Rating.csv")

# %%
movies
# Out:
#                       Film      Genre  Rotten Tomatoes Ratings %  \
# 0    (500) Days of Summer      Comedy                         87
# 1              10,000 B.C.  Adventure                          9
# 2               12 Rounds      Action                         30
# 3                127 Hours  Adventure                         93
# 4                17 Again      Comedy                         55
# ..                     ...        ...                        ...
# 554          Your Highness     Comedy                         26
# 555        Youth in Revolt     Comedy                         68
# 556                 Zodiac   Thriller                         89
# 557            Zombieland      Action                         90
# 558              Zookeeper     Comedy                         14
#
#      Audience Ratings %  Budget (million $)  Year of release
# 0                    81                   8             2009
# 1                    44                 105             2008
# ...

# %%
type(movies)
# pandas dataframes
# Out:
# pandas.core.frame.DataFrame

# %%
len(movies)
# Out:
# 559

# %%
import numpy

# %%
print(numpy.__version__)
# Out:
# 1.23.5

# %%
import pandas

# %%
print(pandas.__version__)
# Out:
# 1.5.3

# %%
movies.columns
# Out:
# Index(['Film', 'Genre', 'Rotten Tomatoes Ratings %', 'Audience Ratings %',
#        'Budget (million $)', 'Year of release'],
#       dtype='object')

# %%
movies.shape
# Out:
# (559, 6)

# %%
movies.head()
# Out:
#                     Film      Genre  Rotten Tomatoes Ratings %  \
# 0  (500) Days of Summer      Comedy                         87
# 1            10,000 B.C.  Adventure                          9
# 2             12 Rounds      Action                         30
# 3              127 Hours  Adventure                         93
# 4              17 Again      Comedy                         55
#
#    Audience Ratings %  Budget (million $)  Year of release
# 0                  81                   8             2009
# 1                  44                 105             2008
# 2                  52                  20             2009
# 3                  84                  18             2010
# 4                  70                  20             2009

# %%
movies.tail()
# Out:
#                 Film     Genre  Rotten Tomatoes Ratings %  Audience Ratings %  \
# 554    Your Highness    Comedy                         26                  36
# 555  Youth in Revolt    Comedy                         68                  52
# 556           Zodiac  Thriller                         89                  73
# 557      Zombieland     Action                         90                  87
# 558        Zookeeper    Comedy                         14                  42
#
#      Budget (million $)  Year of release
# 554                  50             2011
# 555                  18             2009
# 556                  65             2007
# 557                  24             2009
# 558                  80             2011

# %%
movies.info()
# info about there is any null values
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 559 entries, 0 to 558
# Data columns (total 6 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Film                       559 non-null    object
#  1   Genre                      559 non-null    object
#  2   Rotten Tomatoes Ratings %  559 non-null    int64
#  3   Audience Ratings %         559 non-null    int64
#  4   Budget (million $)         559 non-null    int64
#  5   Year of release            559 non-null    int64
# dtypes: int64(4), object(2)
# memory usage: 26.3+ KB

# %%
movies
# Out:
#                       Film      Genre  Rotten Tomatoes Ratings %  \
# 0    (500) Days of Summer      Comedy                         87
# 1              10,000 B.C.  Adventure                          9
# 2               12 Rounds      Action                         30
# 3                127 Hours  Adventure                         93
# 4                17 Again      Comedy                         55
# ..                     ...        ...                        ...
# 554          Your Highness     Comedy                         26
# 555        Youth in Revolt     Comedy                         68
# 556                 Zodiac   Thriller                         89
# 557            Zombieland      Action                         90
# 558              Zookeeper     Comedy                         14
#
#      Audience Ratings %  Budget (million $)  Year of release
# 0                    81                   8             2009
# 1                    44                 105             2008
# ...

# %%
movies.describe()
# mean, meadian & mode
# decriptive statistic
# Out:
#        Rotten Tomatoes Ratings %  Audience Ratings %  Budget (million $)  \
# count                 559.000000          559.000000          559.000000
# mean                   47.309481           58.744186           50.236136
# std                    26.413091           16.826887           48.731817
# min                     0.000000            0.000000            0.000000
# 25%                    25.000000           47.000000           20.000000
# 50%                    46.000000           58.000000           35.000000
# 75%                    70.000000           72.000000           65.000000
# max                    97.000000           96.000000          300.000000
#
#        Year of release
# count       559.000000
# mean       2009.152057
# std           1.362632
# min        2007.000000
# 25%        2008.000000
# 50%        2009.000000
# 75%        2010.000000
# max        2011.000000

# %%
movies.columns
# Out:
# Index(['Film', 'Genre', 'Rotten Tomatoes Ratings %', 'Audience Ratings %',
#        'Budget (million $)', 'Year of release'],
#       dtype='object')

# %%
movies.columns=['Film','Genre','CriticRatings','AudienceRating','BudgetMillions','Year']

# %%
movies.head()
# we cahnge columns name
# Out:
#                     Film      Genre  CriticRatings  AudienceRating  \
# 0  (500) Days of Summer      Comedy             87              81
# 1            10,000 B.C.  Adventure              9              44
# 2             12 Rounds      Action             30              52
# 3              127 Hours  Adventure             93              84
# 4              17 Again      Comedy             55              70
#
#    BudgetMillions  Year
# 0               8  2009
# 1             105  2008
# 2              20  2009
# 3              18  2010
# 4              20  2009

# %%
movies.describe()
# Out:
#        CriticRatings  AudienceRating  BudgetMillions         Year
# count     559.000000      559.000000      559.000000   559.000000
# mean       47.309481       58.744186       50.236136  2009.152057
# std        26.413091       16.826887       48.731817     1.362632
# min         0.000000        0.000000        0.000000  2007.000000
# 25%        25.000000       47.000000       20.000000  2008.000000
# 50%        46.000000       58.000000       35.000000  2009.000000
# 75%        70.000000       72.000000       65.000000  2010.000000
# max        97.000000       96.000000      300.000000  2011.000000

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 559 entries, 0 to 558
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Film            559 non-null    object
#  1   Genre           559 non-null    object
#  2   CriticRatings   559 non-null    int64
#  3   AudienceRating  559 non-null    int64
#  4   BudgetMillions  559 non-null    int64
#  5   Year            559 non-null    int64
# dtypes: int64(4), object(2)
# memory usage: 26.3+ KB

# %%
movies.Year=movies.Year.astype('category')
movies.Genre=movies.Genre.astype('category')

# %%
movies.info()
# now we change object to category
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 559 entries, 0 to 558
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Film            559 non-null    object
#  1   Genre           559 non-null    category
#  2   CriticRatings   559 non-null    int64
#  3   AudienceRating  559 non-null    int64
#  4   BudgetMillions  559 non-null    int64
#  5   Year            559 non-null    category
# dtypes: category(2), int64(3), object(1)
# memory usage: 19.2+ KB

# %%
movies['Film']=movies['Film'].astype('category')

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 559 entries, 0 to 558
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Film            559 non-null    category
#  1   Genre           559 non-null    category
#  2   CriticRatings   559 non-null    int64
#  3   AudienceRating  559 non-null    int64
#  4   BudgetMillions  559 non-null    int64
#  5   Year            559 non-null    category
# dtypes: category(3), int64(3)
# memory usage: 36.5 KB

# %%
movies.describe()
# now Year cant see in describe bcz year cant be in float
# hence we convert year data type to category data type
# Out:
#        CriticRatings  AudienceRating  BudgetMillions
# count     559.000000      559.000000      559.000000
# mean       47.309481       58.744186       50.236136
# std        26.413091       16.826887       48.731817
# min         0.000000        0.000000        0.000000
# 25%        25.000000       47.000000       20.000000
# 50%        46.000000       58.000000       35.000000
# 75%        70.000000       72.000000       65.000000
# max        97.000000       96.000000      300.000000

# %%
movies.head()
# Out:
#                     Film      Genre  CriticRatings  AudienceRating  \
# 0  (500) Days of Summer      Comedy             87              81
# 1            10,000 B.C.  Adventure              9              44
# 2             12 Rounds      Action             30              52
# 3              127 Hours  Adventure             93              84
# 4              17 Again      Comedy             55              70
#
#    BudgetMillions  Year
# 0               8  2009
# 1             105  2008
# 2              20  2009
# 3              18  2010
# 4              20  2009

# %%
movies.Year
# Out:
# 0      2009
# 1      2008
# 2      2009
# 3      2010
# 4      2009
#        ...
# 554    2011
# 555    2009
# 556    2007
# 557    2009
# 558    2011
# Name: Year, Length: 559, dtype: category
# Categories (5, int64): [2007, 2008, 2009, 2010, 2011]

# %%
movies.Genre.cat.categories
# print genre column unique item
# Out:
# Index(['Action', 'Adventure', 'Comedy', 'Drama', 'Horror', 'Romance',
#        'Thriller'],
#       dtype='object')

# %%
from matplotlib import pyplot as plt
import seaborn as sns
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# - basically joint plot is a scatter plot & find the reletion between audience & crictics
# - also if you look up you can find the uniform distribution (critics) & normal distribution (audience)

# %%
movies.head()
# Out:
#                     Film      Genre  CriticRatings  AudienceRating  \
# 0  (500) Days of Summer      Comedy             87              81
# 1            10,000 B.C.  Adventure              9              44
# 2             12 Rounds      Action             30              52
# 3              127 Hours  Adventure             93              84
# 4              17 Again      Comedy             55              70
#
#    BudgetMillions  Year
# 0               8  2009
# 1             105  2008
# 2              20  2009
# 3              18  2010
# 4              20  2009

# %%
y=sns.jointplot(data=movies, x='CriticRatings', y='AudienceRating')
# it is biavariate anlysis
# audience rarings is more dominent then crictic rating
# based on the we found as most people are the most likelyhood to watch audience ratings &  less likely to watch crictic ratings
# let me explaine the excel --> if you filter audience rating & crictic rating. crictic ratings has very low values compare to audience ratings

# %%
y=sns.jointplot(data=movies, x='CriticRatings', y='AudienceRating', kind='hex')
# kind=reg

# %%
movies['AudienceRating']
# Out:
# 0      81
# 1      44
# 2      52
# 3      84
# 4      70
#        ..
# 554    36
# 555    52
# 556    73
# 557    87
# 558    42
# Name: AudienceRating, Length: 559, dtype: int64

# %%
# histograms
y1=sns.distplot(movies.AudienceRating)

# %%
sns.set_style('darkgrid')

# %%
y2=sns.distplot(movies.AudienceRating, bins=12)

# %%
# sns.set_style('darkgrid')
y3=plt.hist(movies.AudienceRating, bins=20)

# %%
sns.set_style('white')    # normal distribution & called as bell curve

# %%
n1=plt.hist(movies.AudienceRating, bins=20)
# now fent the darkgrid

# %%
movies.head()
# Out:
#                     Film      Genre  CriticRatings  AudienceRating  \
# 0  (500) Days of Summer      Comedy             87              81
# 1            10,000 B.C.  Adventure              9              44
# 2             12 Rounds      Action             30              52
# 3              127 Hours  Adventure             93              84
# 4              17 Again      Comedy             55              70
#
#    BudgetMillions  Year
# 0               8  2009
# 1             105  2008
# 2              20  2009
# 3              18  2010
# 4              20  2009

# %%
n1=plt.hist(movies.CriticRatings, bins=20)    #  uniform distribution

# %%
# creating  stacked histograms & this is bit tough to understand

# %%
# h1= plt.hist(movies.BudgetMillions)
plt.hist(movies.BudgetMillions)
plt.show()

# %%
plt.hist(movies[movies.Genre=='Drama'].BudgetMillions)
plt.show()

# %%
movies.head()
# Out:
#                     Film      Genre  CriticRatings  AudienceRating  \
# 0  (500) Days of Summer      Comedy             87              81
# 1            10,000 B.C.  Adventure              9              44
# 2             12 Rounds      Action             30              52
# 3              127 Hours  Adventure             93              84
# 4              17 Again      Comedy             55              70
#
#    BudgetMillions  Year
# 0               8  2009
# 1             105  2008
# 2              20  2009
# 3              18  2010
# 4              20  2009

# %%
# movies.Genre.unique()

# %%
# below plots are stacked histograms beacuse overlaps
plt.hist(movies[movies.Genre=='Action'].BudgetMillions, bins=20)
plt.hist(movies[movies.Genre=='Thriller'].BudgetMillions, bins=20)
plt.hist(movies[movies.Genre=='Drama'].BudgetMillions, bins=20)
plt.legend()
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
plt.hist([movies[movies.Genre=='Action'].BudgetMillions,\
          movies[movies.Genre=='Drama'].BudgetMillions,\
          movies[movies.Genre=='Thriller'].BudgetMillions,\
          movies[movies.Genre=='Comedy'].BudgetMillions],
          bins=20, stacked=True)
plt.show()

# %%
# if you have 100 categories you cannnot copy & paste all the things
for gen in movies.Genre.cat.categories:
    print(gen)
# Out:
# Action
# Adventure
# Comedy
# Drama
# Horror
# Romance
# Thriller

# %%
movies.Genre.cat.categories
# Out:
# Index(['Action', 'Adventure', 'Comedy', 'Drama', 'Horror', 'Romance',
#        'Thriller'],
#       dtype='object')

# %%
movies.head()
# Out:
#                     Film      Genre  CriticRatings  AudienceRating  \
# 0  (500) Days of Summer      Comedy             87              81
# 1            10,000 B.C.  Adventure              9              44
# 2             12 Rounds      Action             30              52
# 3              127 Hours  Adventure             93              84
# 4              17 Again      Comedy             55              70
#
#    BudgetMillions  Year
# 0               8  2009
# 1             105  2008
# 2              20  2009
# 3              18  2010
# 4              20  2009

# %%
vis1=sns.lmplot(data=movies, x='CriticRatings', y='AudienceRating',\
                fit_reg=False)

# %%
vis1=sns.lmplot(data=movies, x='CriticRatings', y='AudienceRating',\
               fit_reg=False, hue='Genre')
# hue used for highliting with the colour

# %%
# !pip install seaborn --upgrade

# %%
vis1=sns.lmplot(data=movies, x='CriticRatings', y='AudienceRating',\
               fit_reg=False, hue='Genre',height=10, aspect=1)
# in this lmplot i dont have size argument
# hence it shows error

# %%
# kernal density estimate plot (KDE plot)
# how can i visualize audience rating & critic rating. using scatter plot

# %%
k1 = sns.kdeplot(data=movies, x='CriticRatings', y='AudienceRating')
# where do u find density & how density is distributed across from the chat
# center point is kernal this is called KDE & instead of dots it visualize like this
# we can able to clearly see the apread at the audience ratings

# %%
k1=sns.kdeplot(data=movies, x='CriticRatings', y='AudienceRating', shade=True, shade_lowest=False, cmap='Reds')

# %%
k2=sns.kdeplot(data=movies,x='CriticRatings', y='AudienceRating', shade_lowest=False, cmap='Greens')

# %%
k2=sns.kdeplot(data=movies,x='CriticRatings', y='AudienceRating', shade_lowest=False, cmap='Greens_r')

# %%
sns.set_style('dark')
k1=sns.kdeplot(data=movies, x='BudgetMillions', y='AudienceRating', shade_lowest=False, cmap='Greens')

# %%
k1=sns.kdeplot(data=movies, x='BudgetMillions', y='AudienceRating', shade_lowest=False, cmap='Greens_r')

# %%
sns.set_style('dark')
k1=sns.kdeplot(data=movies, x='BudgetMillions', y='AudienceRating')

# %%
k2=sns.kdeplot(data=movies, x='BudgetMillions', y='CriticRatings')

# %%
# subplots
f, ax=plt.subplots(1,2, figsize=(12,6))
# f, ax=plt.subplot(3,3, figsize=(12,6))
# for two empty plots

# %%
p, axes=plt.subplots(1,2, figsize=(12,10))

k1=sns.kdeplot(data=movies, x='BudgetMillions', y='AudienceRating', ax=axes[0])
k2=sns.kdeplot(data=movies, x='BudgetMillions', y='AudienceRating', ax=axes[1])

# %%
axes
# Out:
# array([<Axes: xlabel='BudgetMillions', ylabel='AudienceRating'>,
#        <Axes: xlabel='BudgetMillions', ylabel='AudienceRating'>],
#       dtype=object)

# %%
# box plot
w=sns.boxplot(data=movies, x='Genre', y='CriticRatings')

# %%
movies.head()
# Out:
#                     Film      Genre  CriticRatings  AudienceRating  \
# 0  (500) Days of Summer      Comedy             87              81
# 1            10,000 B.C.  Adventure              9              44
# 2             12 Rounds      Action             30              52
# 3              127 Hours  Adventure             93              84
# 4              17 Again      Comedy             55              70
#
#    BudgetMillions  Year
# 0               8  2009
# 1             105  2008
# 2              20  2009
# 3              18  2010
# 4              20  2009

# %%
# violin plot
z=sns.violinplot(data=movies, x='Genre', y='CriticRatings')

# %%
s1=sns.boxplot(data=movies[movies.Genre=='Drama'], x='Year', y='CriticRatings')

# %%
c=sns.violinplot(data=movies[movies.Genre=='Drama'], x='Year', y='CriticRatings')

# %%
# creating a facet grid

# %%
g=sns.FacetGrid(movies, row='Genre', col='Year', hue='Genre')
# kins of subplots

# %%
plt.scatter(data=movies, x='CriticRatings', y='AudienceRating')

# %%
g=sns.FacetGrid(movies, row='Genre', col='Year', hue='Genre')
g=g.map(plt.scatter, 'CriticRatings','AudienceRating')
# scatter plot are mapped in FacetGrid

# %%
# you can populated any type of chat
g=sns.FacetGrid(movies, row='Genre', col='Year', hue='Genre')
g=g.map(plt.hist, 'BudgetMillions')
# scatterplot are mapped in FacetGrid

# %%
# 
g=sns.FacetGrid(movies, row='Genre', col='Year', hue='Genre')
kws=dict(s=50, linewidth=0.5, edgecolor='black')
g=g.map(plt.scatter, 'CriticRatings','AudienceRating', **kws)
# scatterplot are mapped in Facetgrid

# %%
# python is not vectorized programming language
# building dashboard (dashboard - combination of chats)

# %%
sns.set_style('darkgrid')
f, axes=plt.subplots(2,2, figsize=(15,15))

k1=sns.kdeplot(data=movies, x='BudgetMillions', y='AudienceRating', ax=axes[0,0])
k2=sns.kdeplot(data=movies, x='BudgetMillions', y='CriticRatings',  ax=axes[0,1])

k1.set(xlim=(-20,160))
k2.set(xlim=(-20,160))
z=sns.violinplot(data=movies[movies.Genre=='Drama'], x='Year', y='CriticRatings', ax=axes[1,0])
k4=sns.kdeplot(data=movies, x='CriticRatings', y='AudienceRating', shade=True, shade_lowest=False, cmap='Reds', ax=axes[1,1])
k4b=sns.kdeplot(data=movies, x='CriticRatings', y='AudienceRating', cmap='Reds', ax=axes[1,1])

plt.show()

# %%
# how can you style your dashboard using different color map

# python is not vectorized programing 
# building dashboard (dashboard - combination of chats)

# %%
movies.head()
# Out:
#                     Film      Genre  CriticRatings  AudienceRating  \
# 0  (500) Days of Summer      Comedy             87              81
# 1            10,000 B.C.  Adventure              9              44
# 2             12 Rounds      Action             30              52
# 3              127 Hours  Adventure             93              84
# 4              17 Again      Comedy             55              70
#
#    BudgetMillions  Year
# 0               8  2009
# 1             105  2008
# 2              20  2009
# 3              18  2010
# 4              20  2009

# %%
sns.set_style('dark',{'axes.facecolor':'black'})
f, axes=plt.subplots(2,2, figsize=(15,15))

# plot
k1=sns.kdeplot(data=movies, x='BudgetMillions', y='AudienceRating',\
              shade=True, shade_lowest=True, cmap='inferno',\
              ax=axes[0,0])
k1b=sns.kdeplot(data=movies, x='BudgetMillions', y='AudienceRating',\
               cmap='cool', ax=axes[0,0])

# plot [0,1]
k2=sns.kdeplot(data=movies, x='BudgetMillions', y='CriticRatings',\
              shade='True', shade_lowest='True', cmap='inferno',\
              ax=axes[0,1])
k2b=sns.kdeplot(data=movies, x='BudgetMillions', y='CriticRatings',\
               cmap='cool', ax=axes[0,1])

# plot[1,0]
z=sns.violinplot(data=movies[movies.Genre=='Drama'],\
                x='Year', y='CriticRatings', ax=axes[1,0])

# plot [1,1]
k4=sns.kdeplot(data=movies, x='CriticRatings', y='AudienceRating',\
              shade=True, shade_lowest=False, cmap='Blues_r',\
              ax=axes[1,1])
k4b=sns.kdeplot(data=movies, x='CriticRatings', y='AudienceRating',\
               cmap='gist_gray_r', ax=axes[1,1])


k1.set(xlim=(-20,160))
k2.set(xlim=(-20,160))

plt.show()

# %% [markdown]
# ## Final discussion what we learn so far -
# - 1> category datatype in python
# - 2> jointplots
# - 3> histogram
# - 4> stacked histograms
# - 5> Kde plot
# - 6> subplot
# - 7> violin plots
# - 8> Factet grid
# - 9> Building dashboards
